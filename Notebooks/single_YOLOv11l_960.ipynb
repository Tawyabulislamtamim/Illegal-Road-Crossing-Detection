# %%
from google.colab import drive
drive.mount('/content/drive')

# Install YOLO
# !pip install -q ultralytics pyyaml

from ultralytics import YOLO
from pathlib import Path
import yaml
# Out:
# Mounted at /content/drive
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 39.3 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
PROJECT_DIR = Path("/content/drive/MyDrive/Machine_Learning")

DATASET_DIR = PROJECT_DIR / "Dataset/YOLO_Dataset/single_class_road_crossing_960_yolov11"

MODEL_FILE = PROJECT_DIR / "Models" / "yolo11l.pt"

OUTPUT_DIR = PROJECT_DIR / "Experiments/Single_Class/YOLOv11l"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
yaml_dict = {
    "path": str(DATASET_DIR),
    "train": "train/images",
    "val": "valid/images",
    "test": "test/images",
    "nc": 1,
    "names": ["person"]
}

yaml_path = DATASET_DIR / "data.yaml"

with open(yaml_path, "w") as f:
    yaml.dump(yaml_dict, f)

# %%
last_checkpoint = OUTPUT_DIR / "train" / "weights" / "last.pt"

if last_checkpoint.exists():
    print("Resuming training from:", last_checkpoint)
    model = YOLO(str(last_checkpoint))
    resume = True
else:
    print("Starting new training...")
    model = YOLO(str(MODEL_FILE))
    resume = False
# Out:
# Starting new training...

# %%
model.train(
    data=str(yaml_path),

    epochs=50,
    imgsz=960,
    batch=8,

    optimizer="AdamW",
    lr0=5e-4,
    lrf=0.01,
    weight_decay=5e-4,

    dropout=0.05,
    label_smoothing=0.05,
    patience=10,
    cos_lr=True,
    cache=True,
    workers=2,
    amp=True,
    seed=42,

    mosaic=1.0,
    mixup=0.1,
    fliplr=0.5,
    translate=0.1,
    scale=0.5,
    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.4,

    project=str(OUTPUT_DIR),
    name="train",
    exist_ok=True,

    resume=resume,

    save=True,
    save_period=5,
    plots=True
)

best_model = OUTPUT_DIR / "train" / "weights" / "best.pt"

print("\nLoading Best Model...")
model = YOLO(str(best_model))
# Out:
# WARNING ⚠️ 'label_smoothing' is deprecated and will be removed in the future.
# Ultralytics 8.4.105 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=True, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/content/drive/MyDrive/Machine_Learning/Dataset/YOLO_Dataset/single_class_road_crossing_960_yolov11/data.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.05, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=960, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.0005, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.1, mode=train, model=/content/drive/MyDrive/Machine_Learning/Models/yolo11l.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/Machine_Learning/Experiments/Single_Class/YOLOv11l, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/.shortcut-targets-by-id/1v-Gq4tBK6j-LUvTfFIBTi2oS67OiXVxk/Machine_Learning/Experiments/Single_Class/YOLOv11l/train, save_frames=False, save_json=False, save_period=5, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 26.3MB/s 0.0s
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  2    173824  ultralytics.nn.modules.block.C3k2            [128, 256, 2, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  2    691712  ultralytics.nn.modules.block.C3k2            [256, 512, 2, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  2   1455616  ultralytics.nn.modules.block.C2PSA           [512, 512, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   2496512  ultralytics.nn.modules.block.C3k2            [1024, 512, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2    756736  ultralytics.nn.modules.block.C3k2            [1024, 256, 2, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   2365440  ultralytics.nn.modules.block.C3k2            [768, 512, 2, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   2496512  ultralytics.nn.modules.block.C3k2            [1024, 512, 2, True]
#  23        [16, 19, 22]  1   1411795  ultralytics.nn.modules.head.Detect           [1, 16, None, [256, 512, 512]]
# YOLO11l summary: 358 layers, 25,311,251 parameters, 25,311,235 gradients, 87.3 GFLOPs
#
# Remapped 1/1 cls head rows from pretrained weights by class name
# Transferred 1015/1015 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 91.8MB/s 0.1s
# AMP: checks passed ✅
# WARNING ⚠️ train: Slow image access detected (ping: 0.9±0.3 ms, read: 0.3±0.1 MB/s, size: 128.0 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# train: Scanning /content/drive/.shortcut-targets-by-id/1v-Gq4tBK6j-LUvTfFIBTi2oS67OiXVxk/Machine_Learning/Dataset/YOLO_Dataset/single_class_road_crossing_960_yolov11/train/labels... 554 images, 219 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 554/554 4.2it/s 2:13
# train: New cache created: /content/drive/.shortcut-targets-by-id/1v-Gq4tBK6j-LUvTfFIBTi2oS67OiXVxk/Machine_Learning/Dataset/YOLO_Dataset/single_class_road_crossing_960_yolov11/train/labels.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (1.4GB RAM): 100% ━━━━━━━━━━━━ 554/554 99.1it/s 5.6s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# WARNING ⚠️ val: Slow image access detected (ping: 1.7±0.6 ms, read: 0.2±0.0 MB/s, size: 94.3 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /content/drive/.shortcut-targets-by-id/1v-Gq4tBK6j-LUvTfFIBTi2oS67OiXVxk/Machine_Learning/Dataset/YOLO_Dataset/single_class_road_crossing_960_yolov11/valid/labels.cache... 70 images, 29 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 70/70 5.3Mit/s 0.0s
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (0.2GB RAM): 100% ━━━━━━━━━━━━ 70/70 2.3it/s 29.8s
# optimizer: AdamW(lr=0.0005, momentum=0.937) with parameter groups 167 weight(decay=0.0), 174 weight(decay=0.0005), 173 bias(decay=0.0)
# Plotting labels to /content/drive/.shortcut-targets-by-id/1v-Gq4tBK6j-LUvTfFIBTi2oS67OiXVxk/Machine_Learning/Experiments/Single_Class/YOLOv11l/train/labels.jpg...
# Image sizes 960 train, 960 val
# Using 2 dataloader workers
# Logging results to /content/drive/.shortcut-targets-by-id/1v-Gq4tBK6j-LUvTfFIBTi2oS67OiXVxk/Machine_Learning/Experiments/Single_Class/YOLOv11l/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      11.4G      1.114      1.709      1.183          4        960: 100% ━━━━━━━━━━━━ 70/70 1.2s/it 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.0s/it 9.9s
#                    all         70         71      0.617       0.59      0.586       0.38
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      11.5G      1.086      1.386      1.185          0        960: 100% ━━━━━━━━━━━━ 70/70 1.0it/s 1:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.6it/s 3.1s
#                    all         70         71      0.641      0.606      0.685      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      11.5G      1.149      1.466      1.261          1        960: 100% ━━━━━━━━━━━━ 70/70 1.0it/s 1:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.6it/s 3.1s
#                    all         70         71       0.73      0.662      0.724      0.494
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      11.6G      1.152      1.315      1.262          6        960: 100% ━━━━━━━━━━━━ 70/70 1.1it/s 1:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.6it/s 3.2s
#                    all         70         71      0.651      0.657      0.692      0.463
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      11.6G      1.174      1.471      1.243          1        960: 100% ━━━━━━━━━━━━ 70/70 1.1it/s 1:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.6it/s 3.2s
#                    all         70         71      0.704      0.634      0.704      0.442
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      11.6G       1.11      1.318        1.2          4        960: 100% ━━━━━━━━━━━━ 70/70 1.1it/s 1:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.6it/s 3.1s
#                    all         70         71      0.638      0.732      0.736      0.498
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      11.6G      1.096      1.347      1.234          1        960: 100% ━━━━━━━━━━━━ 70/70 1.1it/s 1:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 3.0s
#                    all         70         71      0.654      0.718      0.743      0.503
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      11.5G      1.074        1.2      1.181          4        960: 100% ━━━━━━━━━━━━ 70/70 1.1it/s 1:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 3.0s
#                    all         70         71      0.683      0.732      0.762      0.516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      11.6G     0.6368     0.6163     0.9697          1        960: 100% ━━━━━━━━━━━━ 70/70 1.1it/s 1:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.6it/s 3.1s
#                    all         70         71       0.81       0.72      0.842       0.66
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      11.6G     0.5411     0.5032     0.9443          1        960: 100% ━━━━━━━━━━━━ 70/70 1.0it/s 1:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.6it/s 3.1s
#                    all         70         71      0.898       0.69      0.823      0.623
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      11.5G     0.5271     0.4664     0.9024          1        960: 100% ━━━━━━━━━━━━ 70/70 1.1it/s 1:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.6it/s 3.2s
#                    all         70         71      0.819      0.775       0.84       0.64
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      11.5G     0.5104     0.4477     0.9177          2        960: 100% ━━━━━━━━━━━━ 70/70 1.1it/s 1:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.6it/s 3.1s
#                    all         70         71      0.882      0.704       0.84      0.662
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      11.6G     0.4816     0.5415     0.8833          0        960: 100% ━━━━━━━━━━━━ 70/70 1.1it/s 1:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.6it/s 3.1s
#                    all         70         71      0.869      0.746      0.855      0.676
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      11.6G     0.4613     0.4096     0.8864          3        960: 100% ━━━━━━━━━━━━ 70/70 1.1it/s 1:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.6it/s 3.1s
#                    all         70         71      0.859       0.77      0.855      0.665
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 35, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 45 epochs completed in 0.920 hours.
# Optimizer stripped from /content/drive/.shortcut-targets-by-id/1v-Gq4tBK6j-LUvTfFIBTi2oS67OiXVxk/Machine_Learning/Experiments/Single_Class/YOLOv11l/train/weights/last.pt, 51.3MB
# Optimizer stripped from /content/drive/.shortcut-targets-by-id/1v-Gq4tBK6j-LUvTfFIBTi2oS67OiXVxk/Machine_Learning/Experiments/Single_Class/YOLOv11l/train/weights/best.pt, 51.3MB
#
# Validating /content/drive/.shortcut-targets-by-id/1v-Gq4tBK6j-LUvTfFIBTi2oS67OiXVxk/Machine_Learning/Experiments/Single_Class/YOLOv11l/train/weights/best.pt...
# Ultralytics 8.4.105 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11l summary (fused): 191 layers, 25,280,083 parameters, 0 gradients, 86.6 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.0s/it 5.1s
#                    all         70         71      0.737      0.831      0.869      0.674
# Speed: 0.8ms preprocess, 42.0ms inference, 0.0ms loss, 13.5ms postprocess per image
# Results saved to /content/drive/.shortcut-targets-by-id/1v-Gq4tBK6j-LUvTfFIBTi2oS67OiXVxk/Machine_Learning/Experiments/Single_Class/YOLOv11l/train
#
# Loading Best Model...

# %%
print("\nValidation Results")
metrics = model.val(
    data=str(yaml_path),
    split="val"
)

print(f"Precision : {metrics.box.mp:.4f}")
print(f"Recall    : {metrics.box.mr:.4f}")
print(f"mAP@50    : {metrics.box.map50:.4f}")
print(f"mAP50-95  : {metrics.box.map:.4f}")
# Out:
# Validation Results
# Ultralytics 8.4.105 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.8±0.3 ms, read: 50.5±11.2 MB/s, size: 108.3 KB)
# val: Scanning /content/drive/.shortcut-targets-by-id/1v-Gq4tBK6j-LUvTfFIBTi2oS67OiXVxk/Machine_Learning/Dataset/YOLO_Dataset/single_class_road_crossing_960_yolov11/valid/labels.cache... 70 images, 29 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 70/70 17.3Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7s/it 8.6s
#                    all         70         71      0.733      0.831       0.87      0.676
# Speed: 13.1ms preprocess, 95.7ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /content/runs/detect/val-3
# Precision : 0.7331
# Recall    : 0.8310
# mAP@50    : 0.8699
# mAP50-95  : 0.6763

# %%
print("\nTesting on Test Set")
test_metrics = model.val(
    data=str(yaml_path),
    split="test"
)

print(f"Test Precision : {test_metrics.box.mp:.4f}")
print(f"Test Recall    : {test_metrics.box.mr:.4f}")
print(f"Test mAP@50    : {test_metrics.box.map50:.4f}")
print(f"Test mAP50-95  : {test_metrics.box.map:.4f}")
# Out:
# Testing on Test Set
# Ultralytics 8.4.105 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 0.6±0.1 ms, read: 35.9±4.7 MB/s, size: 89.2 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /content/drive/.shortcut-targets-by-id/1v-Gq4tBK6j-LUvTfFIBTi2oS67OiXVxk/Machine_Learning/Dataset/YOLO_Dataset/single_class_road_crossing_960_yolov11/test/labels.cache... 69 images, 29 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 69/69 18.1Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7s/it 8.5s
#                    all         69         86       0.76      0.812      0.842      0.639
# Speed: 10.8ms preprocess, 98.6ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /content/runs/detect/val-4
# Test Precision : 0.7604
# Test Recall    : 0.8117
# Test mAP@50    : 0.8419
# Test mAP50-95  : 0.6394

# %%
print(f"### Model Performance Summary\n\n"\
      f"| Metric       | Validation Set | Test Set     |\n"\
      f"|:-------------|:---------------|:-------------|\n"\
      f"| Precision    | {metrics.box.mp:.4f}         | {test_metrics.box.mp:.4f}       |\n"\
      f"| Recall       | {metrics.box.mr:.4f}         | {test_metrics.box.mr:.4f}       |\n"\
      f"| mAP@50       | {metrics.box.map50:.4f}         | {test_metrics.box.map50:.4f}       |\n"\
      f"| mAP50-95     | {metrics.box.map:.4f}         | {test_metrics.box.map:.4f}       |\n\n"\
      f"These results indicate how well the model performed on unseen data (validation and test sets) after training. The mAP (mean Average Precision) scores are key indicators of detection performance across different Intersection over Union (IoU) thresholds.")
# Out:
# ### Model Performance Summary
#
# | Metric       | Validation Set | Test Set     |
# |:-------------|:---------------|:-------------|
# | Precision    | 0.7331         | 0.7604       |
# | Recall       | 0.8310         | 0.8117       |
# | mAP@50       | 0.8699         | 0.8419       |
# | mAP50-95     | 0.6763         | 0.6394       |
#
# These results indicate how well the model performed on unseen data (validation and test sets) after training. The mAP (mean Average Precision) scores are key indicators of detection performance across different Intersection over Union (IoU) thresholds.
